# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np
import pandas as pd
import psycopg2
import psycopg2.extras
from datetime import timedelta, datetime
import time

import bb_utils
import bb_utils.meta
import bb_utils.ids
import bb_backend

# bb_backend.api.server_adress = 'localhost:8000'
connect_str = """dbname='beesbook' user='reader' host='tonic.imp.fu-berlin.de' 
                 password='' application_name='mehmed'"""

# %%
observ_period = timedelta(hours=1)
datetime_start = datetime(2016, 8, 25)
num_observ_periods = 72

location_prefix = '/mnt/storage/janek/caches/'

#(First detections are on 20.07.2016, last are 19.09.2016 (3 months duration))
print('Beginning at '+datetime_start.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Beginning at 2016-08-25 00:00:00

# %% [markdown]
# Saves 1-hour periods from the detections database in CSV files.

# %%
for i in range(0,num_observ_periods):
    datetime_end = datetime_start + observ_period
    datetime_str = datetime_start.strftime("%Y-%m-%d_%H:%M:%S")
    
    print('Getting hour #'+str(i)+', beginning at '+datetime_str)
    start = time.time()
    with psycopg2.connect(connect_str) as conn:
        query = """SELECT * FROM bb_detections
               WHERE timestamp >= %s AND
                     timestamp < %s AND
                     bee_id_confidence >= %s
               ;"""
    df = pd.read_sql_query(
        query, conn, 
        params=(datetime_start, datetime_end, 0.99), #note: high confidence requirement
        coerce_float=False)

    end = time.time()
    secs_elapsed = end - start

    m, s = divmod(secs_elapsed, 60)
    h, m = divmod(m, 60)
    print('Getting the data took: %d:%02d:%02d'% (h, m, s))
    
    start = time.time()
    df.to_csv(location_prefix+datetime_str+'.csv')
    datetime_start = datetime_end
    
    end = time.time()
    secs_elapsed = end - start

    m, s = divmod(secs_elapsed, 60)
    h, m = divmod(m, 60)
    print('Saving the csv took: %d:%02d:%02d'% (h, m, s))
# Out:
# Getting hour #0, beginning at 2016-08-25_00:00:00
# Getting the data took: 0:02:09
# Saving the csv took: 0:00:43
# Getting hour #1, beginning at 2016-08-25_01:00:00
# Getting the data took: 0:01:32
# Saving the csv took: 0:00:41
# Getting hour #2, beginning at 2016-08-25_02:00:00
# Getting the data took: 0:02:16
# Saving the csv took: 0:00:45
# Getting hour #3, beginning at 2016-08-25_03:00:00
# Getting the data took: 0:01:32
# Saving the csv took: 0:00:45
# Getting hour #4, beginning at 2016-08-25_04:00:00
# Getting the data took: 0:01:32
# Saving the csv took: 0:00:43
# Getting hour #5, beginning at 2016-08-25_05:00:00
# Getting the data took: 0:02:01
# Saving the csv took: 0:00:42
# Getting hour #6, beginning at 2016-08-25_06:00:00
# Getting the data took: 0:02:21
# Saving the csv took: 0:00:43
# Getting hour #7, beginning at 2016-08-25_07:00:00
# Getting the data took: 0:02:15
# Saving the csv took: 0:00:46
# Getting hour #8, beginning at 2016-08-25_08:00:00
# Getting the data took: 0:01:41
# Saving the csv took: 0:00:50
# Getting hour #9, beginning at 2016-08-25_09:00:00
# Getting the data took: 0:03:00
# Saving the csv took: 0:00:50
# Getting hour #10, beginning at 2016-08-25_10:00:00
# Getting the data took: 0:02:46
# Saving the csv took: 0:00:47
# Getting hour #11, beginning at 2016-08-25_11:00:00
# Getting the data took: 0:02:12
# Saving the csv took: 0:00:43
# Getting hour #12, beginning at 2016-08-25_12:00:00
# Getting the data took: 0:02:09
# Saving the csv took: 0:00:41
# Getting hour #13, beginning at 2016-08-25_13:00:00
# Getting the data took: 0:01:23
# Saving the csv took: 0:00:41
# Getting hour #43, beginning at 2016-08-26_19:00:00
# Getting the data took: 0:01:32
# Saving the csv took: 0:00:26
# Getting hour #44, beginning at 2016-08-26_20:00:00
# Getting the data took: 0:01:21
# Saving the csv took: 0:00:26
# Getting hour #45, beginning at 2016-08-26_21:00:00
# Getting the data took: 0:00:49
# Saving the csv took: 0:00:26
# Getting hour #46, beginning at 2016-08-26_22:00:00
# Getting the data took: 0:00:48
# Saving the csv took: 0:00:24
# Getting hour #47, beginning at 2016-08-26_23:00:00
# Getting the data took: 0:00:51
# Saving the csv took: 0:00:27
# Getting hour #48, beginning at 2016-08-27_00:00:00
# Getting the data took: 0:01:06
# Saving the csv took: 0:00:26
# Getting hour #49, beginning at 2016-08-27_01:00:00
# Getting the data took: 0:01:37
# Saving the csv took: 0:00:24
# Getting hour #50, beginning at 2016-08-27_02:00:00
# Getting the data took: 0:00:56
# Saving the csv took: 0:00:23
# Getting hour #51, beginning at 2016-08-27_03:00:00
# Getting the data took: 0:03:48
# Saving the csv took: 0:00:24
# Getting hour #52, beginning at 2016-08-27_04:00:00
# Getting the data took: 0:01:04
# Saving the csv took: 0:00:25
# Getting hour #53, beginning at 2016-08-27_05:00:00
# Getting the data took: 0:01:02
# Saving the csv took: 0:00:26
# Getting hour #54, beginning at 2016-08-27_06:00:00
# Getting the data took: 0:01:11
# Saving the csv took: 0:00:26
# Getting hour #55, beginning at 2016-08-27_07:00:00
# Getting the data took: 0:00:46
# Saving the csv took: 0:00:25
# Getting hour #56, beginning at 2016-08-27_08:00:00
# Getting the data took: 0:02:46
# Saving the csv took: 0:00:26
# Getting hour #57, beginning at 2016-08-27_09:00:00
# Getting the data took: 0:01:00
# Saving the csv took: 0:00:27
# Getting hour #58, beginning at 2016-08-27_10:00:00
# Getting the data took: 0:01:31
# Saving the csv took: 0:00:26
# Getting hour #59, beginning at 2016-08-27_11:00:00
# Getting the data took: 0:00:39
# Saving the csv took: 0:00:26
# Getting hour #60, beginning at 2016-08-27_12:00:00
# Getting the data took: 0:00:42
# Saving the csv took: 0:00:26
# Getting hour #61, beginning at 2016-08-27_13:00:00
# Getting the data took: 0:00:54
# Saving the csv took: 0:00:23
# Getting hour #62, beginning at 2016-08-27_14:00:00
# Getting the data took: 0:01:27
# Saving the csv took: 0:00:24
# Getting hour #63, beginning at 2016-08-27_15:00:00
# Getting the data took: 0:00:30
# Saving the csv took: 0:00:21
# Getting hour #64, beginning at 2016-08-27_16:00:00
# Getting the data took: 0:01:32
# Saving the csv took: 0:00:25
# Getting hour #65, beginning at 2016-08-27_17:00:00
# Getting the data took: 0:00:41
# Saving the csv took: 0:00:24
# Getting hour #66, beginning at 2016-08-27_18:00:00
# Getting the data took: 0:01:17
# Saving the csv took: 0:00:22
# Getting hour #67, beginning at 2016-08-27_19:00:00
# Getting the data took: 0:01:25
# Saving the csv took: 0:00:24
# Getting hour #68, beginning at 2016-08-27_20:00:00
# Getting the data took: 0:00:59
# Saving the csv took: 0:00:23
# Getting hour #69, beginning at 2016-08-27_21:00:00
# Getting the data took: 0:00:34
# Saving the csv took: 0:00:23
# Getting hour #70, beginning at 2016-08-27_22:00:00
# Getting the data took: 0:01:04
# Saving the csv took: 0:00:22
# Getting hour #71, beginning at 2016-08-27_23:00:00
# Getting the data took: 0:00:47
# Saving the csv took: 0:00:21
