# %%
import pandas as pd
import sys
sys.path.append('/home/mi/rrszynka/mnt/janek/Beesbook-janek/Python-modules/')
from bee_cache import Cache, CacheType, CacheFormat; c = Cache()
import seaborn as sns

# %%
g02 = c.load('gaps_02_displayable')
g02['confidence_threshold'] = 0.2

# %%
g099 = c.load('gaps_099_displayable')
g099['confidence_threshold'] = 0.99

# %%
g = g099.append(g02)
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
# sns.set_style("dark")
# sns.set_context("paper")
# sns.set(font_scale=1.2)

# %%
grid = sns.catplot(y="disappear_reason", data=g, col='confidence_threshold', kind="count", height=5, aspect=6/5)

# %%
grid.savefig('/home/mi/rrszynka/mnt/janek/caches/Illustrations/catplot_02_vs_099_5x6_f12.png')

# %%
g02.real_gap.value_counts()
# Out:
# True     94
# False     6
# Name: real_gap, dtype: int64

# %%
g099.real_gap.value_counts()
# Out:
# True     88
# False    12
# Name: real_gap, dtype: int64

# %%
g099.possible_trip.value_counts()
# Out:
# False    98
# True      2
# Name: possible_trip, dtype: int64

# %%
g02.possible_trip.value_counts()
# Out:
# False    99
# True      1
# Name: possible_trip, dtype: int64

# %%
g.possible_trip.value_counts()/2
# Out:
# False    98.5
# True      1.5
# Name: possible_trip, dtype: float64

# %%
g.real_gap.value_counts()/2
# Out:
# True     91.0
# False     9.0
# Name: real_gap, dtype: float64
